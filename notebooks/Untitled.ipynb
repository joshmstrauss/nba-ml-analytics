# %%
# API endpoint tests
import pandas as pd
from nba_api.stats.endpoints import leaguegamelog

# %%
# Get team game logs for a specific season:
def get_team_game_logs(season: str, season_type: str = "Regular Season") -> pd.DataFrame:
    gamelog = leaguegamelog.LeagueGameLog(
        season=season,
        season_type_all_star=season_type,
        player_or_team_abbreviation="T"   # "T" for team logs, "P" for player logs
    )
    df = gamelog.get_data_frames()[0]
    return df

# %%
get_team_game_logs("2024-25")
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0        22024  1610612738               BOS          Boston Celtics
# 1        22024  1610612750               MIN  Minnesota Timberwolves
# 2        22024  1610612747               LAL      Los Angeles Lakers
# 3        22024  1610612752               NYK         New York Knicks
# 4        22024  1610612744               GSW   Golden State Warriors
# ...        ...         ...               ...                     ...
# 2455     22024  1610612747               LAL      Los Angeles Lakers
# 2456     22024  1610612759               SAS       San Antonio Spurs
# 2457     22024  1610612763               MEM       Memphis Grizzlies
# 2458     22024  1610612738               BOS          Boston Celtics
# 2459     22024  1610612756               PHX            Phoenix Suns
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  FGM  ...  DREB  REB  AST  \
# 0     0022400061  2024-10-22  BOS vs. NYK  W  240   48  ...    29   40   33
# 1     0022400062  2024-10-22    MIN @ LAL  L  240   35  ...    35   47   17
# 2     0022400062  2024-10-22  LAL vs. MIN  W  240   42  ...    31   46   22
# 3     0022400061  2024-10-22    NYK @ BOS  L  240   43  ...    29   34   20
# 4     0022400072  2024-10-23    GSW @ POR  W  240   48  ...    42   57   38
# ...          ...         ...          ... ..  ...  ...  ...   ...  ...  ...
# 2455  0022401199  2025-04-13    LAL @ POR  L  240   31  ...    29   42   21
# 2456  0022401197  2025-04-13  SAS vs. TOR  W  240   43  ...    41   50   22
# 2457  0022401194  2025-04-13  MEM vs. DAL  W  240   52  ...    34   53   31
# 2458  0022401187  2025-04-13  BOS vs. CHA  W  240   35  ...    34   49   22
# 2459  0022401200  2025-04-13    PHX @ SAC  L  240   40  ...    28   37   28
#
#       STL  BLK  TOV  PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE
# 0       6    3    4  15  132          23                1
# 1       4    1   16  22  103          -7                1
# 2       7    8    7  22  110           7                1
# 3       2    3   12  12  109         -23                1
# 4      13    5   18  27  140          36                1
# ...   ...  ...  ...  ..  ...         ...              ...
# 2455    9   11   21  21   81         -28                1
# 2456   11    2   12  13  125           7                1
# 2457   13    7   12  15  132          35                1
# 2458   12    6   13  14   93           7                1
# 2459    6    1   13   9   98         -11                1
#
# [2460 rows x 29 columns]

# %%
# get player logs for a specific season:
def get_player_game_logs(season: str, season_type: str = "Regular Season") -> pd.DataFrame:
    gamelog = leaguegamelog.LeagueGameLog(
        season=season,
        season_type_all_star=season_type,
        player_or_team_abbreviation="P"   # "T" for team logs, "P" for player logs
    )
    df = gamelog.get_data_frames()[0]
    return df

# %%
get_player_game_logs("2024-25")
# Out:
#       SEASON_ID  PLAYER_ID        PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0         22024     201143         Al Horford  1610612738               BOS
# 1         22024     201950       Jrue Holiday  1610612738               BOS
# 2         22024       2544       LeBron James  1610612747               LAL
# 3         22024    1630559      Austin Reaves  1610612747               LAL
# 4         22024     201144        Mike Conley  1610612750               MIN
# ...         ...        ...                ...         ...               ...
# 26301     22024    1629162  Jordan McLaughlin  1610612759               SAS
# 26302     22024    1642264     Stephon Castle  1610612759               SAS
# 26303     22024    1631119    Jaylin Williams  1610612760               OKC
# 26304     22024    1642382    Branden Carlson  1610612760               OKC
# 26305     22024    1630194          Paul Reed  1610612765               DET
#
#                     TEAM_NAME     GAME_ID   GAME_DATE      MATCHUP WL  ...  \
# 0              Boston Celtics  0022400061  2024-10-22  BOS vs. NYK  W  ...
# 1              Boston Celtics  0022400061  2024-10-22  BOS vs. NYK  W  ...
# 2          Los Angeles Lakers  0022400062  2024-10-22  LAL vs. MIN  W  ...
# 3          Los Angeles Lakers  0022400062  2024-10-22  LAL vs. MIN  W  ...
# 4      Minnesota Timberwolves  0022400062  2024-10-22    MIN @ LAL  L  ...
# ...                       ...         ...         ...          ... ..  ...
# 26301       San Antonio Spurs  0022401197  2025-04-13  SAS vs. TOR  W  ...
# 26302       San Antonio Spurs  0022401197  2025-04-13  SAS vs. TOR  W  ...
# 26303   Oklahoma City Thunder  0022401196  2025-04-13    OKC @ NOP  W  ...
# 26304   Oklahoma City Thunder  0022401196  2025-04-13    OKC @ NOP  W  ...
# 26305         Detroit Pistons  0022401192  2025-04-13    DET @ MIL  L  ...
#
#        REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  FANTASY_PTS  \
# 0        3    5    1    1    0   2   11          19         28.1
# 1        4    4    1    0    0   2   18          23         31.8
# 2        5    4    0    2    2   3   16          -6         32.0
# 3        9    4    1    1    0   4   12          12         34.8
# 4        4    2    1    0    3   1    5         -22         12.8
# ...    ...  ...  ...  ...  ...  ..  ...         ...          ...
# 26301    0    0    0    0    0   1    2           0          2.0
# 26302    8    6    0    0    4   2   20           2         34.6
# 26303    2    0    0    0    0   0    0           9          2.4
# 26304   10    2    0    3    2   3   26           8         48.0
# 26305    6    5    0    1    1   3    8           0         24.7
#
#        VIDEO_AVAILABLE
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 26301                1
# 26302                1
# 26303                1
# 26304                1
# 26305                1
#
# [26306 rows x 32 columns]
